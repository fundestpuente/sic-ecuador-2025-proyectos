# %%
import sys
import os

# Agregar la carpeta src al path
sys.path.append(os.path.join(os.getcwd(), 'src'))
from Graficas import *
from ProcesamientoDatos import *
from ObtencionDatos import *
from ExportarResultados import *

# %%
print("="*60)
print("OBTENCION DE DATOS DE UN CSV")
print("="*60)
print()
df = obtener_datos("Data/Finzen.csv")
print(df.head())
# Out:
# ============================================================
# OBTENCION DE DATOS DE UN CSV
# ============================================================
#
#    id       Start time  Completion time      Email  Name        nombre  \
# 0   1  02/10/2025 8:51  02/10/2025 8:56  anonymous   NaN         Isaac
# 1   2  02/10/2025 8:57  02/10/2025 9:00  anonymous   NaN        Xavier
# 2   3  02/10/2025 9:04  02/10/2025 9:05  anonymous   NaN    Alejandra
# 3   4  02/10/2025 9:03  02/10/2025 9:06  anonymous   NaN        Mathew
# 4   5  02/10/2025 9:10  02/10/2025 9:14  anonymous   NaN  María Belén
#
#             apellido  edad      cedula                       Correo  ...  \
# 0            Andrade    24  1750844597      isacarias08@hotmail.com  ...
# 1            Espinel    26  1004329155    edison.espinel@epn.edu.ec  ...
# 2              Ruiz     22  1728732601          Ruiz.03jb@gmail.com  ...
# 3         Gutierrez     23  1726711490  mathew.gutierrez@epn.edu.ec  ...
# 4  Figueroa Sánchez     21  1317470910  figueroabelen1705@gmail.com  ...
#
#   trabajo_actual          ocupacion emprendimiento_actual nombre_negocio  \
# 0             Si  Personal de apoyo                    Si         ALICUP
# 1             No                NaN                    No            NaN
# 2             No                NaN                    No            NaN
# 3             No                NaN                    No            NaN
# 4             No                NaN                    No            NaN
#
#   tipo_ingreso              ingresos  \
# 0           Si      {'Trabajo': 150}
# 1           Si  {'Mensualidad': 500}
# 2           No   {'sin registro': 0}
# 3           Si  {'Mensualidad': 100}
# 4           No   {'sin registro': 0}
#
#                                  gastos_prioritarios   gastos_secundarios  \
# 0                                {'Universidad': 70}       {'Pareja': 25}
# 1  {'Comida': 100, 'ServiciosBásicos': 100, 'Otro...        {'Ropa': 100}
# 2                                {'sin registro': 0}  {'sin registro': 0}
# 3                                     {'Comida': 55}    {'Materiales': 5}
# 4                                {'sin registro': 0}  {'sin registro': 0}
#
#   porcentaje_ahorro dificultad_equilibrio
# 0              10.0                   3.0
# 1              20.0                   3.0
# 2               NaN                   NaN
# 3              10.0                   4.0
# 4               NaN                   NaN
#
# [5 rows x 24 columns]

# %%
print("="*60)
print("PROCESAMIENTO DE DATOS DE UN CSV")
print("="*60)
print()
df_procesado = procesar_datos(df)
print(df_procesado)
# Out:
# ============================================================
# PROCESAMIENTO DE DATOS DE UN CSV
# ============================================================
#
#     id        nombre           apellido  edad      cedula  \
# 0    1         Isaac            Andrade    24  1750844597
# 1    2        Xavier            Espinel    26  1004329155
# 2    3    Alejandra               Ruiz     22  1728732601
# 3    4        Mathew         Gutierrez     23  1726711490
# 4    5  María Belén   Figueroa Sánchez     21  1317470910
# ..  ..           ...                ...   ...         ...
# 74  75      Damaris           Cunalata     21  1711576106
# 75  76        Paola           Guitarra     21  1003871132
# 76  77    Giannirley           Calderón    21  1726984642
# 77  78      Fernanda          Cisneros     20  1727762070
# 78  79         Karen               Vera    20  1728993677
#
#                                   Correo     genero  apoyo_familiar  \
# 0                isacarias08@hotmail.com  Masculino               1
# 1              edison.espinel@epn.edu.ec  Masculino               1
# 2                    Ruiz.03jb@gmail.com   Femenino               1
# 3            mathew.gutierrez@epn.edu.ec  Masculino               1
# 4            figueroabelen1705@gmail.com   Femenino               1
# ..                                   ...        ...             ...
# 74           damariscunalata61@gmail.com   Femenino               1
# 75           paolaguitarra2004@gmail.com   Femenino               1
# 76  giannirleycalderon@yachaytech.edu.ec   Femenino               1
# 77        Mikaelaccisneros2020@gmail.com   Femenino               1
# 78                            Sin correo   Femenino               1
#
#     estudio_actual                                 carrera  trabajo_actual  \
# 0                1                        Ingeniería Civil               1
# 1                1   Ing. En Tecnologías de la Información               0
# 2                1                    Matemática aplicada                0
# 3                1          Tecnologías de la Información                0
# 4                1                               Economía                0
# ..             ...                                     ...             ...
# 74               1                    Mecánica automotriz                0
# 75               1  Carrera de Administración de Empresas                1
# 76               1          ING. Ciencias computacionales                0
# 77               1                             Enfermería                0
# 78               1                               Biología                0
#
#                ocupacion  emprendimiento_actual nombre_negocio  tipo_ingreso  \
# 0      Personal de apoyo                      1         ALICUP             1
# 1            Sin trabajo                      0    Sin negocio             1
# 2            Sin trabajo                      0    Sin negocio             0
# 3            Sin trabajo                      0    Sin negocio             1
# 4            Sin trabajo                      0    Sin negocio             0
# ..                   ...                    ...            ...           ...
# 74           Sin trabajo                      0    Sin negocio             0
# 75  Atención al cliente                       0    Sin negocio             1
# 76           Sin trabajo                      0    Sin negocio             0
# 77           Sin trabajo                      0    Sin negocio             1
# 78           Sin trabajo                      0    Sin negocio             1
#
#                           ingresos  \
# 0                 {'Trabajo': 150}
# 1             {'Mensualidad': 500}
# 2              {'sin registro': 0}
# 3             {'Mensualidad': 100}
# 4              {'sin registro': 0}
# ..                             ...
# 74             {'sin registro': 0}
# 75  {'trabajo': 15, 'familia': 75}
# 76             {'sin registro': 0}
# 77                 {'Familia': 40}
# 78            {'Mensualidad': 165}
#
#                                   gastos_prioritarios  \
# 0                                 {'Universidad': 70}
# 1   {'Comida': 100, 'ServiciosBásicos': 100, 'Otro...
# 2                                 {'sin registro': 0}
# 3                                      {'Comida': 55}
# 4                                 {'sin registro': 0}
# ..                                                ...
# 74                                {'sin registro': 0}
# 75                 {'Universidad': 36, 'Trabajo': 25}
# 76                                {'sin registro': 0}
# 77                                {'Universidad': 30}
# 78  {'Comida': 80, 'Vivienda': 65, 'Lavandería': 7...
#
#              gastos_secundarios  porcentaje_ahorro  dificultad_equilibrio
# 0                {'Pareja': 25}               10.0                    3.0
# 1                 {'Ropa': 100}               20.0                    3.0
# 2           {'sin registro': 0}                0.0                    0.0
# 3             {'Materiales': 5}               10.0                    4.0
# 4           {'sin registro': 0}                0.0                    0.0
# ..                          ...                ...                    ...
# 74          {'sin registro': 0}                0.0                    0.0
# 75  {'pareja': 10, 'dulces': 5}                0.0                    3.0
# 76          {'sin registro': 0}                0.0                    0.0
# 77                {'Comida': 2}                0.0                    5.0
# 78            {'Medicinas': 25}                5.0                    4.0
#
# [63 rows x 20 columns]

# %%
print("="*60)
print("FILTRADO DE DATOS")
print("="*60)
print()
df_finanzas, df_estadisticas, df_equilibrio, df_tipo_ingreso = filtrar_datos(df_procesado)

print("--- df_finanzas (Ingresos = 1) ---")
print(df_finanzas.head())
print("\n--- df_estadisticas (Todos) ---")
print(df_estadisticas.head())
print("\n--- df_equilibrio (Ingresos = 1) ---")
print(df_equilibrio.head())
print("\n--- df_tipo_ingreso (Todos) ---")
print(df_tipo_ingreso.head())
# Out:
# ============================================================
# FILTRADO DE DATOS
# ============================================================
#
# --- df_finanzas (Ingresos = 1) ---
#          nombre       apellido      cedula  edad     genero  \
# 0         Isaac        Andrade  1750844597    24  Masculino
# 1        Xavier        Espinel  1004329155    26  Masculino
# 3        Mathew     Gutierrez   1726711490    23  Masculino
# 5  Maria Emilia  Guerra Cedeño  1724658537    18   Femenino
# 7      Joselyn       Amaguaña   1751385905    19   Femenino
#
#                        ingresos  \
# 0              {'Trabajo': 150}
# 1          {'Mensualidad': 500}
# 3          {'Mensualidad': 100}
# 5           {'Mensualidad': 50}
# 7  {'Beca': 27, 'Familia': 100}
#
#                                  gastos_prioritarios  \
# 0                                {'Universidad': 70}
# 1  {'Comida': 100, 'ServiciosBásicos': 100, 'Otro...
# 3                                     {'Comida': 55}
# 5                   {'lavanderia': 10, 'comida': 40}
# 7        {'Pasaje': 15, 'Comida': 10, 'Mascota': 10}
#
#           gastos_secundarios  porcentaje_ahorro
# 0             {'Pareja': 25}               10.0
# 1              {'Ropa': 100}               20.0
# 3          {'Materiales': 5}               10.0
# 5              {'comida': 5}               25.0
# 7  {'Ropa': 25, 'Helado': 5}               30.0
#
# --- df_estadisticas (Todos) ---
#          nombre           apellido      cedula  edad     genero  \
# 0         Isaac            Andrade  1750844597    24  Masculino
# 1        Xavier            Espinel  1004329155    26  Masculino
# 2    Alejandra               Ruiz   1728732601    22   Femenino
# 3        Mathew         Gutierrez   1726711490    23  Masculino
# 4  María Belén   Figueroa Sánchez   1317470910    21   Femenino
#
#    estudio_actual  trabajo_actual  emprendimiento_actual
# 0               1               1                      1
# 1               1               0                      0
# 2               1               0                      0
# 3               1               0                      0
# 4               1               0                      0
#
# --- df_equilibrio (Ingresos = 1) ---
#          nombre       apellido      cedula  edad     genero  \
# 0         Isaac        Andrade  1750844597    24  Masculino
# 1        Xavier        Espinel  1004329155    26  Masculino
# 3        Mathew     Gutierrez   1726711490    23  Masculino
# 5  Maria Emilia  Guerra Cedeño  1724658537    18   Femenino
# 7      Joselyn       Amaguaña   1751385905    19   Femenino
#
#    dificultad_equilibrio
# 0                    3.0
# 1                    3.0
# 3                    4.0
# 5                    5.0
# 7                    2.0
#
# --- df_tipo_ingreso (Todos) ---
#          nombre           apellido      cedula  edad     genero  tipo_ingreso
# 0         Isaac            Andrade  1750844597    24  Masculino             1
# 1        Xavier            Espinel  1004329155    26  Masculino             1
# 2    Alejandra               Ruiz   1728732601    22   Femenino             0
# 3        Mathew         Gutierrez   1726711490    23  Masculino             1
# 4  María Belén   Figueroa Sánchez   1317470910    21   Femenino             0

# %%
print("="*60)
print("GRAFICAS")
print("="*60)
print("Personales (orientados al usuario)")

grafico_finanzas_personales(df_finanzas, '1728186071')
grafico_comparativo_completo(df_finanzas, '1750844597')
# Out:
# ============================================================
# GRAFICAS
# ============================================================
# Personales (orientados al usuario)

# %%
print("="*60)
print("GRAFICAS")
print("="*60)
print("Generales(orientados a los datos)")
proporcion_ingresos(df_tipo_ingreso)
dificultad_financiera_general(df_equilibrio)
edad_vs_ahorro(df_finanzas)
# Out:
# ============================================================
# GRAFICAS
# ============================================================
# Generales(orientados a los datos)
# c:\Users\59399\source\repos\SIC25--FINZEN-GESTI-N-Y-MANEJO-DE-FINANZAS-PERSONALES-MEDIANTE-VISUALIZACI-N-DE-DATOS-EN-J-VENES\src\Graficas.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   datos_agrupados = df_finanzas.groupby('grupo_edad').agg({

# %%
#====================================================================#
#         4.             Interpretación de Datos                     #
#====================================================================#

# 1️.- Edad con mayores gastos

if "edad" in df_finanzas.columns and ("total_gastos" in df_finanzas.columns or "gastos_prioritarios" in df_finanzas.columns):
    # Calcular total_gastos si no existe
    if "total_gastos" not in df_finanzas.columns:
        def _sumar_gastos(fila):
            gp = sum(fila["gastos_prioritarios"].values()) if isinstance(fila.get("gastos_prioritarios"), dict) else 0
            gs = sum(fila["gastos_secundarios"].values()) if isinstance(fila.get("gastos_secundarios"), dict) else 0
            return gp + gs
        df_finanzas["total_gastos"] = df_finanzas.apply(_sumar_gastos, axis=1)

    # Promedio de gasto por edad
    promedio_por_edad = (
        df_finanzas.groupby("edad")["total_gastos"]
        .mean()
        .reset_index()
        .sort_values("total_gastos", ascending=False)
    )

    edad_max_gasto = promedio_por_edad.iloc[0]
    print("\n EDAD CON MAYORES GASTOS")
    print("-" * 50)
    print(f"La edad con mayor gasto promedio es {int(edad_max_gasto['edad'])} años, con un gasto medio de ${edad_max_gasto['total_gastos']:.2f}.")
    print("Esto puede reflejar que a medida que los jóvenes avanzan en edad, asumen más responsabilidades económicas o consumos personales.")

#2.- Correlación entre género y gastos
print("\nCORRELACIÓN ENTRE GÉNERO Y GASTOS ")
print("-" * 50)

df_corr = df_finanzas.copy()

# Convertir 'genero' a valores numéricos (0,1,2)
if "genero" in df_corr.columns:
    df_corr["genero_num"] = df_corr["genero"].astype("category").cat.codes

# Seleccionar solo columnas numéricas relevantes
columnas_numericas = [c for c in df_corr.columns if pd.api.types.is_numeric_dtype(df_corr[c])]

if len(columnas_numericas) >= 2:
    matriz_correlacion = df_corr[columnas_numericas].corr()

    print("Matriz de correlación (valores redondeados a 3 decimales):")
    print(matriz_correlacion.round(3))

    # Interpretación enfocada 
    if "genero_num" in matriz_correlacion.columns and "total_gastos" in matriz_correlacion.columns:
        corr_gen_gasto = matriz_correlacion.loc["genero_num", "total_gastos"]
        print("\n Interpretación del resultado:")
        if abs(corr_gen_gasto) < 0.2:
            print(f"- Correlación débil ({corr_gen_gasto:.3f}): el género tiene poca influencia en el nivel de gastos.")
        elif abs(corr_gen_gasto) < 0.5:
            print(f"- Correlación moderada ({corr_gen_gasto:.3f}): se observan ligeras diferencias en el comportamiento de gasto entre géneros.")
        else:
            print(f"- Correlación fuerte ({corr_gen_gasto:.3f}): existe una clara relación entre el género y el nivel de gasto.")
        print("En el contexto del proyecto FINZEN, esto puede reflejar diferentes patrones de consumo y prioridades financieras entre jóvenes según su género.")


# 3️.- Ahorro y dificultad percibida

if "ahorro_real" in df_finanzas.columns and "dificultad_equilibrio" in df_finanzas.columns:
    correlacion_ahorro_dificultad = df_finanzas["ahorro_real"].corr(df_finanzas["dificultad_equilibrio"])
    print("\n RELACIÓN ENTRE AHORRO Y DIFICULTAD FINANCIERA")
    print("-" * 50)
    print(f"Coeficiente de correlación: {correlacion_ahorro_dificultad:.3f}")
    if correlacion_ahorro_dificultad < -0.5:
        print(" Correlación negativa fuerte: a mayor ahorro, menor dificultad para equilibrar las finanzas.")
    elif correlacion_ahorro_dificultad < -0.2:
        print("Correlación negativa moderada: quienes logran ahorrar suelen sentir menos presión económica.")
    else:
        print("Correlación baja o nula: el ahorro real no parece influir directamente en la dificultad percibida.")
# Out:
#  EDAD CON MAYORES GASTOS
# --------------------------------------------------
# La edad con mayor gasto promedio es 26 años, con un gasto medio de $330.00.
# Esto puede reflejar que a medida que los jóvenes avanzan en edad, asumen más responsabilidades económicas o consumos personales.
#
# CORRELACIÓN ENTRE GÉNERO Y GASTOS
# --------------------------------------------------
# Matriz de correlación (valores redondeados a 3 decimales):
#                     edad  porcentaje_ahorro  ahorro_real  total_gastos  \
# edad               1.000             -0.095        0.076         0.296
# porcentaje_ahorro -0.095              1.000        0.912         0.115
# ahorro_real        0.076              0.912        1.000         0.312
# total_gastos       0.296              0.115        0.312         1.000
# genero_num         0.221              0.270        0.287         0.170
#
#                    genero_num
# edad                    0.221
# porcentaje_ahorro       0.270
# ahorro_real             0.287
# total_gastos            0.170
# genero_num              1.000
#
#  Interpretación del resultado:
# - Correlación débil (0.170): el género tiene poca influencia en el nivel de gastos.
# En el contexto del proyecto FINZEN, esto puede reflejar diferentes patrones de consumo y prioridades financieras entre jóvenes según su género.

# %%
#====================================================================#
#             5.             Exportar  Datos                         #
#====================================================================#

out_dir = os.path.join(os.getcwd(), "out")
dfs = {
    "finanzas": df_finanzas,
    "estadisticas": df_estadisticas,
    "equilibrio": df_equilibrio,
    "tipo_ingreso": df_tipo_ingreso,
}
#Guardar dataframes creados
guardar_resultados_csv(dfs, carpeta_salida=os.path.join(out_dir, "csv"))
#Crear excel con una página por dataframe
guardar_resultados_excel(dfs, carpeta_salida=out_dir, nombre="analisis_finzen.xlsx")
# Out:
# Archivo guardado: c:\Users\59399\source\repos\SIC25--FINZEN-GESTI-N-Y-MANEJO-DE-FINANZAS-PERSONALES-MEDIANTE-VISUALIZACI-N-DE-DATOS-EN-J-VENES\out\csv\finanzas.csv  (34 filas)
# Archivo guardado: c:\Users\59399\source\repos\SIC25--FINZEN-GESTI-N-Y-MANEJO-DE-FINANZAS-PERSONALES-MEDIANTE-VISUALIZACI-N-DE-DATOS-EN-J-VENES\out\csv\estadisticas.csv  (63 filas)
# Archivo guardado: c:\Users\59399\source\repos\SIC25--FINZEN-GESTI-N-Y-MANEJO-DE-FINANZAS-PERSONALES-MEDIANTE-VISUALIZACI-N-DE-DATOS-EN-J-VENES\out\csv\equilibrio.csv  (34 filas)
# Archivo guardado: c:\Users\59399\source\repos\SIC25--FINZEN-GESTI-N-Y-MANEJO-DE-FINANZAS-PERSONALES-MEDIANTE-VISUALIZACI-N-DE-DATOS-EN-J-VENES\out\csv\tipo_ingreso.csv  (63 filas)
# Excel guardado en: c:\Users\59399\source\repos\SIC25--FINZEN-GESTI-N-Y-MANEJO-DE-FINANZAS-PERSONALES-MEDIANTE-VISUALIZACI-N-DE-DATOS-EN-J-VENES\out\analisis_finzen.xlsx
# 'c:\\Users\\59399\\source\\repos\\SIC25--FINZEN-GESTI-N-Y-MANEJO-DE-FINANZAS-PERSONALES-MEDIANTE-VISUALIZACI-N-DE-DATOS-EN-J-VENES\\out\\analisis_finzen.xlsx'
